# %% [markdown]
# In modern software development environments, maintaining high productivity while preventing developer burnout is a critical challenge for organizations. Burnout not only reduces individual performance but also leads to higher turnover, missed deadlines, and reduced code quality. This project aims to build a predictive model that estimates a developer’s productivity and classifies their burnout level based on work patterns, behavioral metrics, and environmental factors. The goal is to enable early intervention by identifying at-risk developers and optimizing team performance.

# %%
# mount to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read an excel file from drive
data = pd.read_csv('/content/drive/MyDrive/developer_burnout_dataset_7000.csv')

# %%
data.head()
# Out:
#     age  experience_years  daily_work_hours  sleep_hours  caffeine_intake  \
# 0  26.0              12.0             10.33         4.45              2.0
# 1  39.0              10.0              8.62         5.77              5.0
# 2  34.0              13.0               NaN         4.03              5.0
# 3  30.0               1.0              6.85         6.47              2.0
# 4  27.0               7.0              4.24         5.80              NaN
#
#    bugs_per_day  commits_per_day  meetings_per_day  screen_time  \
# 0          11.0              4.0               1.0        15.07
# 1          15.0             11.0               5.0        13.25
# 2           2.0             18.0               9.0        11.18
# 3          15.0             26.0               1.0        11.14
# 4           9.0             17.0               7.0         8.05
#
#    exercise_hours  stress_level burnout_level
# 0            0.14         55.96        Medium
# 1            0.54         82.22          High
# 2            1.54         61.77        Medium
# 3            0.96         54.98        Medium
# 4            0.36         27.90           Low

# %%
# show the values of caffeine_intake
data['caffeine_intake'].unique()
# Out:
# array([ 2.,  5., nan,  0.,  6.,  4.,  3.,  7.,  1.])

# %%
# show the type of the data
data.dtypes
# Out:
# age                 float64
# experience_years    float64
# daily_work_hours    float64
# sleep_hours         float64
# caffeine_intake     float64
# bugs_per_day        float64
# commits_per_day     float64
# meetings_per_day    float64
# screen_time         float64
# exercise_hours      float64
# stress_level        float64
# burnout_level        object
# dtype: object

# %%
# create a smaller subset of the dataset of first 50 samples
data_smaller = data.iloc[:30]

# %%
# create a scatter plot using the smaller dataset
plt.scatter(data_smaller['caffeine_intake'], data_smaller['bugs_per_day'])
plt.xlabel('Caffeine Intake')
plt.ylabel('Bugs Introduced per Day')
plt.title('Caffeine Intake vs. Bugs Introduced per Day')
plt.show()

# %% [markdown]
# There is no visible trend in the scatter plot above which tells us that there is no apparent relation between the amount of caffeine intake against productivity. But the sample used here is too small to make any judgements.
